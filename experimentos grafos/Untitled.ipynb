# %%
from model import read
import matplotlib.pyplot as plt

# %%
vertices,edges=read("30k.graph")

# %%
grados=[]

# %%
for vertice in vertices:
    grados.append(len(vertice[2:]))
grados.sort()

# %%
np.mean(grados)
# Out:
# 134.8664

# %%
fdp={}
for i in grados:
    if i not in fdp:
        fdp[i]=1
    else:
        fdp[i]+=1

# %%
plt.plot(np.log(np.array(fdp.keys())),np.log(np.array(fdp.values())))

# %%
fdp
# Out:
# {1: 6301,
#  2: 4806,
#  3: 3043,
#  4: 1909,
#  5: 1305,
#  6: 880,
#  7: 655,
#  8: 492,
#  9: 434,
#  10: 316,
#  11: 257,
#  12: 226,
#  13: 189,
#  14: 156,
#  15: 139,
#  16: 131,
#  17: 91,
#  18: 83,
#  19: 92,
#  20: 89,
#  21: 64,
#  22: 69,
#  23: 53,
#  24: 65,
#  25: 48,
#  26: 39,
#  27: 38,
#  28: 49,
#  29: 36,
#  30: 32,
#  31: 31,
#  32: 23,
#  33: 29,
#  34: 25,
#  35: 21,
#  36: 17,
#  37: 19,
#  38: 34,
#  39: 26,
#  40: 13,
#  41: 16,
#  42: 18,
#  43: 16,
#  44: 17,
#  45: 10,
#  46: 9,
#  47: 15,
#  48: 14,
#  49: 9,
#  50: 21,
#  51: 12,
#  52: 9,
#  53: 10,
#  54: 15,
#  55: 10,
#  56: 11,
#  57: 5,
#  58: 2,
#  59: 9,
#  60: 5,
#  61: 7,
#  62: 3,
#  63: 8,
#  64: 3,
#  65: 8,
#  66: 7,
#  67: 7,
#  68: 6,
#  69: 1,
#  70: 7,
#  71: 8,
#  72: 4,
#  73: 8,
#  74: 8,
#  75: 7,
#  76: 3,
#  77: 4,
#  78: 5,
#  79: 3,
#  80: 4,
#  81: 6,
#  82: 3,
#  83: 1,
#  84: 3,
#  85: 2,
#  86: 7,
#  87: 4,
#  88: 5,
#  89: 2,
#  90: 4,
#  91: 1,
#  92: 4,
#  93: 2,
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")
from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.5000000000000002, 'B': 0.3000000000000001, 'C': 0.20000000000000004}

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="simulate.pdf")
# Out:
# 0.5442994939856317

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6793597455398941

# %%
mixing_matrix(G)
# Out:
# array([[0.356, 0.112, 0.034],
#        [0.112, 0.072, 0.054],
#        [0.034, 0.054, 0.172]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.06
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.10430438136449534
# assortativity for node attributes: 0.3587194910797882
# Coeficiente de agrupamiento de G:0.07087449024405547
# Centro de G:[0, 1, 4, 9, 11, 13, 25, 26, 32, 33, 35, 44, 46, 47, 50, 51, 57, 66, 70, 71, 72, 99]
# Diametro de G:7
# Periferia de G:
# [68, 81]
# Radio de G:4
# Coeficiente de Small World: 1.4039142088201786
# Omega coeficiente: 0.7878014294532808

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")
from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="uniform_graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.34000000000000014, 'B': 0.3300000000000001, 'C': 0.3300000000000001}

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="uniform_simulate.pdf")
# Out:
# 0.6242594298067935

# %%
homofilia(vecinos)
# Out:
# 0.5992063492063492

# %%
assor(G)
# Out:
# 0.6984503104118288

# %%
mixing_matrix(G)
# Out:
# array([[0.21428571, 0.12896825, 0.02579365],
#        [0.12896825, 0.13095238, 0.04563492],
#        [0.02579365, 0.04563492, 0.25396825]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 252
# Average degree:   5.0400
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.18
# Densidad de G: 0.05090909090909091
# degree assortativity:-0.09718165644594222
# assortativity for node attributes: 0.3969006208236576
# Coeficiente de agrupamiento de G:0.1977698837110602
# Centro de G:[10, 39, 49, 53, 64, 74, 90, 97, 98]
# Diametro de G:9
# Periferia de G:
# [38, 81]
# Radio de G:5
# Coeficiente de Small World: 2.6264339209190823
# Omega coeficiente: 0.36078743657172485

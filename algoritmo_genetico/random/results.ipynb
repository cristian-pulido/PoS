# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0)

# %%
plt.plot(p_gen[20:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos)
# Out:
# 0.48640803637494245

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
mixing_matrix(G)
# Out:
# array([[0.484, 0.054, 0.142],
#        [0.054, 0.084, 0.004],
#        [0.142, 0.004, 0.032]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.232
# Densidad de G: 0.0505050505051
# degree assortativity:-0.19629169461384824
# assortativity for node attributes: 0.176534527907
# Coeficiente de agrupamiento de G:0.229270828722
# Centro de G:[0]
# Diametro de G:6
# Periferia de G:
# [51, 88]
# Radio de G:3
# Coeficiente de Small World: 1.0853198836383013
# Omega coeficiente: 0.5654322619516032

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.5000000000000002, 'B': 0.3000000000000001, 'C': 0.20000000000000004}

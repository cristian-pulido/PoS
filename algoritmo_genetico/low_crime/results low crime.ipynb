# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
lamda={"A":0,"B":0.05,"C":0.2}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="low_crime_graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.34000000000000014, 'B': 0.3300000000000001, 'C': 0.3300000000000001}

# %%
plot(modelo=modelo,lamda=lamda,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="low_crime_simulate.pdf")
# Out:
# 0.5935905033587363

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6949098763774819

# %%
mixing_matrix(G)
# Out:
# array([[0.196, 0.098, 0.05 ],
#        [0.098, 0.104, 0.052],
#        [0.05 , 0.052, 0.3  ]])

# %%
plt.plot(p_gen)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.102
# Densidad de G: 0.050505050505050504
# degree assortativity:0.36122117540017945
# assortativity for node attributes: 0.38981975275496383
# Coeficiente de agrupamiento de G:0.09932459207459209
# Centro de G:[3, 6, 7, 11, 19, 21, 24, 31, 32, 39, 47, 56, 62, 85, 89, 90, 92, 94, 95, 97, 98, 99]
# Diametro de G:6
# Periferia de G:
# [29, 36, 42, 55, 60, 61, 68, 73, 74, 78, 80, 82, 83]
# Radio de G:4
# Coeficiente de Small World: 3.4690297733820747
# Omega coeficiente: 0.4587375071171964

# %%
# import matplotlib as mpl
# mpl.use('Agg')
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
vertices=read("g.graph")[0]

# %%
n=len(vertices)
s=np.random.rand(n)

# %%
plot(vertices=vertices,s=s,modelo="g_m_v",legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="simulate_g_generated.pdf")
# Out:
# 0.5342837955822035

# %%
G=convert_vertices_to_graph(vertices)

# %%
draw_graph(G,crime=3,fear=s,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="graph_generate.pdf")

# %%
assor(G)
# Out:
# 0.9771475614602849

# %%
mixing_matrix(G)
# Out:
# array([[0.32608696, 0.00652174, 0.00217391],
#        [0.00652174, 0.3       , 0.00652174],
#        [0.00217391, 0.00652174, 0.34347826]])

# %%
solucion=convert_vecinos_to_solution(vertices)

# %%
porcentaje(vertices)
# Out:
# {'A': 0.3300000000000001, 'B': 0.3000000000000001, 'C': 0.37000000000000016}

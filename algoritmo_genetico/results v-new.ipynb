# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("new_nu_0.9/solucion_sg__g_m_v.npy")
p_gen = np.load("new_nu_0.9/solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
nu=0.9

# %%
lamda
# Out:
# {'A': 0, 'B': 0.05, 'C': 0.5}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="new_nu_0.9/nu_9.pdf")

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,nu=nu,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="new_nu_0.9/simulate_nu_9.pdf")
# Out:
# 0.6736988048071939

# %%
homofilia(vecinos)
# Out:
# 0.58

# %%
assor(G)
# Out:
# 0.6711803685285165

# %%
mixing_matrix(G)
# Out:
# array([[0.312, 0.106, 0.052],
#        [0.106, 0.108, 0.052],
#        [0.052, 0.052, 0.16 ]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.175
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.11461750129873004
# assortativity for node attributes: 0.34236073705703296
# Coeficiente de agrupamiento de G:0.1925300255300255
# Centro de G:[0]
# Diametro de G:6
# Periferia de G:
# [48, 52, 71, 79, 80, 81, 88, 93, 97, 99]
# Radio de G:3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-39fa159414c4> in <module>
# ----> 1 ver_medidas(G)
#
# ~/all/PoS/algoritmo genetico/pos.py in ver_medidas(G)
#     643     """
#     644
# --> 645     print("Coeficiente de Small World: " + str(smallworld.sigma(G)))
#     646
#     647     """
#
# ...

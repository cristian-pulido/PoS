# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("n_03/solucion_sg__g_m_v.npy")
p_gen = np.load("n_03/solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
nu=0.3

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="n_03/nu_3.pdf")

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,nu=nu,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="n_03/simulate_nu_3.pdf")
# Out:
# 0.18904485540106442

# %%
homofilia(vecinos)
# Out:
# 0.5776892430278885

# %%
assor(G)
# Out:
# 0.5818967549304628

# %%
mixing_matrix(G)
# Out:
# array([[0.44621514, 0.14143426, 0.05976096],
#        [0.14143426, 0.10756972, 0.00996016],
#        [0.05976096, 0.00996016, 0.02390438]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 249
# Average degree:   4.9800
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.063
# Densidad de G: 0.0503030303030303
# degree assortativity:-0.05224828754511308
# assortativity for node attributes: 0.22552977583688086
# Coeficiente de agrupamiento de G:0.06926695526695525
# Centro de G:[0, 1, 2, 3, 4, 7, 9, 10, 12, 14, 15, 16, 18, 20, 21, 22, 25, 26, 29, 34, 37, 45, 46, 48, 49, 67, 68, 75, 76, 81]
# Diametro de G:6
# Periferia de G:
# [47, 50, 55, 62, 83, 84, 86, 95, 97, 98]
# Radio de G:4
# Coeficiente de Small World: 1.0117398436481837
# Omega coeficiente: 0.8552172973604482

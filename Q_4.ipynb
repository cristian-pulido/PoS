# %%
from pos import *
from simulate import g
import matplotlib.pyplot as plt

# %%
Q=use_Q(500,500,"4.graph")

# %%
vertices=read("4.graph")[0]
soriginal=np.array(Q.keys()[np.random.randint(len(Q.keys()))])#mod.generate("small.graph")
s0=soriginal.copy()
vertices
# Out:
# [[0, 0.05, 3], [1, 0, 2, 3], [2, 0, 1], [3, 0.05, 0, 1]]

# %%
p=g(vertices,soriginal)
p,homofilia(vertices)
# Out:
# (0.5467350020133007, 0.6666666666666666)

# %%
for i in range(5):
    s,r,a,vertices=exec_act(s0,vertices,0.9,0.85,Q,False)
    print(s)
    p=g(vertices,s)
    print("Accion:",a)
    print("PoS",p)
    print("Porcentaje",porcentaje(vertices,True))
    print("Homofilia",homofilia(vertices))
    print("-------------------------------")
    s0=s
    plt.show()
# Out:
# [0.36180593 0.3526622  0.3526622  0.35512802]
# ('Accion:', '>< con (3, 2)')
# ('PoS', 0.2754184500774528)
# ('Porcentaje', {0: 0.5, 0.05: 0.5})
# ('Homofilia', 0.5)
# -------------------------------
# [0.48254543 0.21724256 0.21724256 0.28847534]
# ('Accion:', 'Cambio de nivel de crimen del sujeto 3 a cero')
# ('PoS', 0.14643785667273873)
# ('Porcentaje', {0: 0.75, 0.05: 0.25})
# ('Homofilia', 0.75)
# -------------------------------
# [0.37119254 0.34217818 0.34976846 0.34976846]
# ('Accion:', '>< con (2, 0)')
# ('PoS', 0.28216193856320576)
# ('Porcentaje', {0: 0.75, 0.05: 0.25})
# ('Homofilia', 0.6)
# -------------------------------
# [0.59451647 0.45604671 0.45604671 0.45604671]
# ('Accion:', '>< con (0, 1)')
# ('PoS', 0.38137931509855166)
# ('Porcentaje', {0: 0.75, 0.05: 0.25})
# ('Homofilia', 0.5)
# -------------------------------
# [0.07257368 0.07256344 0.07256611 0.07256611]
# ('Accion:', '<> des (0, 1)')
# ('PoS', 0.031873343387780056)
# ...

# %%
import mod
import numpy as np

# %%
vertices=mod.read("low_range.graph")[0]
rango=[]
for vertice in vertices:
    rango.append(len(vertice[2:]))
np.mean(rango)
# Out:
# 3.054

# %%
G=mod.generate(file="low_range.graph",
               lamda=[0,0.05,0.5],
               colores=["violet","red","green"],
               legend=["i","s","h"],
               pesos=True
              )
# Out:
# Tamano poblacion
# 1000
# Porcentaje grupos con distinta media de crimen
# [0.278 0.463 0.259]
# Vector media de crimen por grupos
# [0, 0.05, 0.5]
# velocidad de olvido
# 0.9
# impacto de la inseguridad nu
# 0.9
# Grafica PoS individual
# PoS media por grupos

# %%
H=mod.generate(file="low_range.graph",
               lamda=[0,0.05,0.5],
               colores=["violet","red","green"],
               legend=["i","s","h"],
               pesos=False
              )
# Out:
# Tamano poblacion
# 1000
# Porcentaje grupos con distinta media de crimen
# [0.278 0.463 0.259]
# Vector media de crimen por grupos
# [0, 0.05, 0.5]
# velocidad de olvido
# 0.9
# impacto de la inseguridad nu
# 0.9
# Grafica PoS individual
# PoS media por grupos

# %%
import matplotlib.pyplot as plt
plt.plot(H[0][0])

# %%
plt.plot(G[0][0])

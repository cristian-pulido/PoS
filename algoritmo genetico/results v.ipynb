# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("n_01/solucion_sg__g_m_v.npy")
p_gen = np.load("n_01/solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
nu=0.1

# %%
lamda
# Out:
# {'A': 0, 'B': 0.05, 'C': 0.5}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="n_01/nu_1.pdf")

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,nu=nu,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="n_01/simulate_nu_1.pdf",draw=True)
# Out:
# 0.06781451105156892

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6056035842746261

# %%
mixing_matrix(G)
# Out:
# array([[0.476, 0.116, 0.052],
#        [0.116, 0.116, 0.032],
#        [0.052, 0.032, 0.008]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.136
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.1100245930260711
# assortativity for node attributes: 0.21120716854925217
# Coeficiente de agrupamiento de G:0.13949687605538663
# Centro de G:[0]
# Diametro de G:5
# Periferia de G:
# [45, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 65, 67, 68, 72, 73, 74, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 87, 88, 89, 90, 91, 94, 95, 96, 97, 98, 99]
# Radio de G:3

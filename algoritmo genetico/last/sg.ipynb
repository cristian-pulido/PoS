# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0)

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos)
# Out:
# 0.47655945705594766

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
mixing_matrix(G)
# Out:
# array([[0.436, 0.02 , 0.162],
#        [0.02 , 0.052, 0.018],
#        [0.162, 0.018, 0.112]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.04
# Densidad de G: 0.0505050505051
# degree assortativity:-0.08393477679764877
# assortativity for node attributes: 0.237677049505
# Coeficiente de agrupamiento de G:0.0445014430014
# Centro de G:[2, 26, 30, 42, 48, 49, 72]
# Diametro de G:6
# Periferia de G:
# [9, 10, 37, 43, 53, 57, 68, 80, 81, 82, 84, 85, 86, 87, 90, 92, 93, 94, 95, 96, 99]
# Radio de G:4
# Coeficiente de Small World: 0.5942046482354875
# Omega coeficiente: 0.9166057747236683

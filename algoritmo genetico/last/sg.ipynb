# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="graph_100_3g_sg.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.5000000000000002, 'B': 0.3000000000000001, 'C': 0.20000000000000004}

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="simulate_100_3g_sg.pdf")
# Out:
# 0.46723547914086583

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6188385247526262

# %%
mixing_matrix(G)
# Out:
# array([[0.436, 0.162, 0.02 ],
#        [0.162, 0.112, 0.018],
#        [0.02 , 0.018, 0.052]])

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.059
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.08393477679764877
# assortativity for node attributes: 0.23767704950525256
# Coeficiente de agrupamiento de G:0.04450144300144299
# Centro de G:[2, 26, 30, 42, 48, 49, 72]
# Diametro de G:6
# Periferia de G:
# [9, 10, 37, 43, 53, 57, 68, 80, 81, 82, 84, 85, 86, 87, 90, 92, 93, 94, 95, 96, 99]
# Radio de G:4
# Coeficiente de Small World: 0.64339165516167

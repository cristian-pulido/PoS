# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sag__g_m_v.npy")
p_gen = np.load("solucion_sag__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sag"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0)

# %%
plt.plot(p_gen[:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos)
# Out:
# 0.49584782948032

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
mixing_matrix(G)
# Out:
# array([[0.44 , 0.022, 0.156],
#        [0.022, 0.096, 0.022],
#        [0.156, 0.022, 0.064]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.153
# Densidad de G: 0.0505050505051
# degree assortativity:-0.07472759576424
# assortativity for node attributes: 0.259138526278
# Coeficiente de agrupamiento de G:0.151142857143
# Centro de G:[0, 1, 2, 16, 20, 22, 32, 36, 40, 42, 47, 52, 58, 59, 60, 61, 62, 63, 64, 66, 67, 69, 97]
# Diametro de G:6
# Periferia de G:
# [51, 55, 70, 73, 81, 85, 87, 92]
# Radio de G:4
# Coeficiente de Small World: 1.4953304040204018
# Omega coeficiente: 0.634566127367429

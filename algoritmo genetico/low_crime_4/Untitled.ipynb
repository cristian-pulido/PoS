# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
lamda={"A":0,"B":0.001,"C":0.03}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="low_crime4_graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.34000000000000014, 'B': 0.3300000000000001, 'C': 0.3300000000000001}

# %%
plot(modelo=modelo,lamda=lamda,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="low_crime4_simulate.pdf")
# Out:
# 0.296179694902851

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6789438537011352

# %%
mixing_matrix(G)
# Out:
# array([[0.128, 0.064, 0.06 ],
#        [0.064, 0.104, 0.076],
#        [0.06 , 0.076, 0.368]])

# %%
plt.plot(p_gen)

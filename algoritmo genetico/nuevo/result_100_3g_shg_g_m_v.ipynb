# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_shg__g_m_v.npy")
p_gen = np.load("solucion_shg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.5,0.35,0.15])
s0=np.random.rand(n)
crimen=3
tipo="shg"
modelo="g_m_v"

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0)

# %%
plt.plot(p_gen[20:])

# %%
plot(modelo=modelo,s=s0,vertices=vecinos)
# Out:
# 0.44773955151085915

# %%
plot(modelo='g_1_v',s=s0,vertices=vecinos)
# Out:
# 0.40727215446494275

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
mixing_matrix(G)
# Out:
# array([[0.436, 0.012, 0.172],
#        [0.012, 0.032, 0.016],
#        [0.172, 0.016, 0.132]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.042
# Densidad de G: 0.0505050505051
# degree assortativity:0.09477147935484218
# assortativity for node attributes: 0.215070643642
# Coeficiente de agrupamiento de G:0.0523919413919
# Centro de G:[0, 6, 16, 17, 31, 33, 43, 49, 53, 75, 81]
# Diametro de G:7
# Periferia de G:
# [88, 90, 92]
# Radio de G:4
# Coeficiente de Small World: 0.8451929967426709
# Omega coeficiente: 0.8709877749443806

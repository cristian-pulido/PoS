# %%
from pos import *
from medidas import *
s0=np.random.rand(100)

# %%
low_rank=read("g.graph")[0]
for v in low_rank:
    if v[1] == 0:
        v[1] ='A'
    elif v[1] == 1:
        v[1] ='B'
    else:
        v[1]='C'
plot(low_rank,s0)
# Out:
# 0.5386429808858421

# %%
homofilia(low_rank)
# Out:
# 0.9695652173913043

# %%
G=draw_graph(low_rank,s0)
grafica_grado_nodos(low_rank)
porcentaje(low_rank)
# Out:
# {'A': 0.3300000000000001, 'B': 0.3000000000000001, 'C': 0.37000000000000016}

# %%
quien_habla(low_rank)
# Out:
# {'A': {'A': 0.974, 'B': 0.019, 'C': 0.006},
#  'B': {'A': 0.021, 'B': 0.958, 'C': 0.021},
#  'C': {'A': 0.006, 'B': 0.019, 'C': 0.975}}

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 230
# Average degree:   4.6000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.097
# Densidad de G: 0.0464646464646
# degree assortativity:-0.0632191516062927
# assortativity for node attributes: 0.954295122921
# Coeficiente de agrupamiento de G:0.116904761905
# Centro de G:[3, 6, 46, 64, 71]
# Diametro de G:9
# Periferia de G:
# [0, 56, 69, 95, 98]
# Radio de G:5

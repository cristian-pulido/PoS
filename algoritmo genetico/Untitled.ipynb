# %%
from pos import *

# %%
n=100
crimen=3
lamda={"A":0,"B":0.05,"C":0.2}
tipo="sg"
modelo="g_m_v"

# %%
s0=np.random.rand(100)

# %%
d_c=dist_crimen(crimen=crimen,
                n=n,
                porcentaje=np.array([0.34,0.33,0.33]))

# %%
estate=generate_estate(n=n)

# %%
vecinos=convert_state_to_vecinos(estate,d_c)

# %%
G=convert_vertices_to_graph(vecinos)

# %%
print(function.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 455
# Average degree:   9.1000

# %%
plot(vecinos,s0,lamda)
# Out:
# 0.6410525441952071

# %%
mixing_matrix(G)
# Out:
# array([[0.14945055, 0.10879121, 0.1010989 ],
#        [0.10879121, 0.10989011, 0.10879121],
#        [0.1010989 , 0.10879121, 0.1032967 ]])

# %%
# draw_graph(G,crime=crimen,fear=s0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
lamda={"A":0,"B":0.01,"C":0.06}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="low_crime3_graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.34000000000000014, 'B': 0.3300000000000001, 'C': 0.3300000000000001}

# %%
plot(modelo=modelo,lamda=lamda,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="low_crime3_simulate.pdf")
# Out:
# 0.3317624660226168

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6956897496135259

# %%
mixing_matrix(G)
# Out:
# array([[0.232, 0.088, 0.054],
#        [0.088, 0.108, 0.058],
#        [0.054, 0.058, 0.26 ]])

# %%
plt.plot(p_gen)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.116
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.026214940507176245
# assortativity for node attributes: 0.39137949922705195
# Coeficiente de agrupamiento de G:0.13137193917193915
# Centro de G:[0, 11, 30, 33, 63, 95, 99]
# Diametro de G:7
# Periferia de G:
# [58, 85]
# Radio de G:4
# Coeficiente de Small World: 2.0555118278279676
# Omega coeficiente: 0.5937801514406378

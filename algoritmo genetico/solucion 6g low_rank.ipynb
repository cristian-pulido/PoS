# %%
from pos import *
from medidas import *
s0=np.random.rand(100)
lamda={"A":0,"B":0.025,"C":0.05,"D":0.15,"E":0.25,"F":0.5}

# %%
low_rank=read("6g_low_rank.graph")[0]
for v in low_rank:
    if v[1] == 0:
        v[1] ='A'
    elif v[1] == 1:
        v[1] ='B'
    elif v[1] == 2:
        v[1] ='C'
    elif v[1] == 3:
        v[1] ='D'
    elif v[1] == 4:
        v[1] ='E'
    else:
        v[1]='F'
plot(low_rank,s0,lamda)
# Out:
# 0.5946613944515451

# %%
homofilia(low_rank)
# Out:
# 0.8921568627450981

# %%
G=draw_graph(low_rank,s0)
grafica_grado_nodos(low_rank)
porcentaje(low_rank)
# Out:
# {'A': 0.17,
#  'B': 0.13999999999999999,
#  'C': 0.26000000000000006,
#  'D': 0.19000000000000003,
#  'E': 0.10999999999999999,
#  'F': 0.12999999999999998}

# %%
quien_habla(low_rank)
# Out:
# {'A': {'A': 0.919, 'B': 0.027, 'C': 0.014, 'D': 0.041},
#  'B': {'A': 0.032, 'B': 0.889, 'D': 0.048, 'E': 0.016, 'F': 0.016},
#  'C': {'A': 0.01, 'C': 0.898, 'D': 0.071, 'E': 0.01, 'F': 0.01},
#  'D': {'A': 0.042, 'B': 0.042, 'C': 0.097, 'D': 0.806, 'F': 0.014},
#  'E': {'B': 0.018, 'C': 0.018, 'E': 0.945, 'F': 0.018},
#  'F': {'B': 0.022, 'C': 0.022, 'D': 0.022, 'E': 0.022, 'F': 0.913}}

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 204
# Average degree:   4.0800
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.311
# Densidad de G: 0.0412121212121
# degree assortativity:-0.16878320406829783
# assortativity for node attributes: 0.869049529506
# Coeficiente de agrupamiento de G:0.298243145743
# Centro de G:[5, 6, 27, 33, 42, 45, 58, 59, 61, 73, 89]
# Diametro de G:10
# Periferia de G:
# [79, 81, 88, 90, 92, 98]
# Radio de G:6
# Coeficiente de Small World: 5.032393189213917
# Omega coeficiente: -0.11634379380971993

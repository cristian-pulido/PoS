# %%
# import matplotlib as mpl
# mpl.use('Agg')
import warnings
warnings.filterwarnings('ignore')

# %%
from pos import *

# %%
n=30
folder="test"
total_generaciones=2
individuos=100
porcentaje_crimen=np.array([0.5,0.3,0.2])
s0=np.random.rand(n)
crimen=3
tipo="sag"
lamda={"A":0,"B":0.05,"C":0.5}
modelo="g_m_v"

# %%
solution, distr_crimen, p_gen=run(folder=folder,
                           total_generaciones=total_generaciones,
                           individuos=individuos,
                           porcentaje_crimen=porcentaje_crimen,
                           s0=s0,
                           n=n,
                           crimen=crimen,
                           tipo_objetivo=tipo,
                           lamda=lamda,
                           min_porcent=min_porcent,
                           modelo=modelo)
# Out:
# Generacion 0/2
#
# Media de crimen:0.6571580207920541
# Homofilia: 0.3333333333333333
# Puntaje Generacion 0.032907514984355624
# Generacion 1/2
#
# Media de crimen:0.6506555774846888
# Homofilia: 0.3333333333333333
# Puntaje Generacion 0.037383299123980696
# Mejor Solucion:
# Media de crimen:0.653414630221969
# Homofilia: 0.3333333333333333

# %%
# import matplotlib as mpl
# mpl.use('Agg')
import warnings
warnings.filterwarnings('ignore')

# %%
from pos import *

# %%
n=50
folder="test"
total_generaciones=10
individuos=500
porcentaje_crimen=np.array([0.6,0.4])
s0=np.random.rand(n)
crimen=2
tipo="shg"
lamda={"A":0,"B":0.05}

# %%
solution, distr_crimen=run(folder=folder,
                           total_generaciones=total_generaciones,
                           individuos=individuos,
                           porcentaje_crimen=porcentaje_crimen,
                           s0=s0,
                           n=n,
                           crimen=crimen,
                           tipo_objetivo=tipo,
                           lamda=lamda,
                           min_porcent=min_porcent)
# Out:
# Generacion 0/10
# Media de crimen:0.38429350373227505
# Homofilia: 0.508992805755
# Puntaje Generacion -194.66465719725534
# Generacion 1/10
# Media de crimen:0.3450425377251355
# Homofilia: 0.508992805755
# Puntaje Generacion -181.4345649835438
# Generacion 2/10
# Media de crimen:0.3908693458234754
# Homofilia: 0.474358974359
# Puntaje Generacion -172.59206938896025
# Generacion 3/10
# Media de crimen:0.3701329177392475
# Homofilia: 0.484517304189
# Puntaje Generacion -164.7878782180333
# Generacion 4/10
# Media de crimen:0.41391534110073325
# Homofilia: 0.494485294118
# Puntaje Generacion -157.65918034553826
# Generacion 5/10
# Media de crimen:0.3911499205375534
# Homofilia: 0.489833641405
# Puntaje Generacion -151.22193950530271
# Generacion 6/10

# %%
vecinos=convert_state_to_vecinos(state=solution,dist_crimen=distr_crimen,n=n)

# %%
G=draw_graph(vecinos,s0)

# %%
quien_habla(vecinos)

# %%
porcentaje(vecinos)

# %%
homofilia(vecinos)

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)

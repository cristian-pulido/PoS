# %%
# import matplotlib as mpl
# mpl.use('Agg')
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
vertices=read("g.graph")[0]

# %%
n=len(vertices)
s=np.random.rand(n)

# %%
plot(vertices=vertices,s=s,modelo="g_m_v")
# Out:
# 0.556676502707747

# %%
G=convert_vertices_to_graph(vertices)

# %%
draw_graph(G,crime=3,fear=s)

# %%
assor(G)
# Out:
# 0.9771475614602849

# %%
mixing_matrix(G)
# Out:
# array([[0.32608696, 0.00217391, 0.00652174],
#        [0.00217391, 0.34347826, 0.00652174],
#        [0.00652174, 0.00652174, 0.3       ]])

# %%
solucion=convert_vecinos_to_solution(vertices)

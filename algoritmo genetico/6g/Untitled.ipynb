# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/runlab/scripts/cpulido_POS/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.3,0.25,0.2,0.15,0.1])
s0=np.random.rand(n)
crimen=5
tipo="sg"
modelo="g_m_v"
lamda={"A":0,"B":0.05,"C":0.1,"D":0.25,"E":0.5}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0)

# %%
plt.plot(p_gen)

# %%
plot(modelo=modelo,s=s0,vertices=vecinos,lamda=lamda)
# Out:
# 0.5917073717867284

# %%
homofilia(vecinos)
# Out:
# 0.570281124497992

# %%
mixing_matrix(G)
# Out:
# array([[0.26506024, 0.04216867, 0.05823293, 0.00803213, 0.02208835],
#        [0.04216867, 0.10040161, 0.03413655, 0.00401606, 0.01606426],
#        [0.05823293, 0.03413655, 0.14859438, 0.01004016, 0.01606426],
#        [0.00803213, 0.00401606, 0.01004016, 0.02008032, 0.00401606],
#        [0.02208835, 0.01606426, 0.01606426, 0.00401606, 0.03614458]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 249
# Average degree:   4.9800
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.044
# Densidad de G: 0.050303030303
# degree assortativity:0.12697533970810285
# assortativity for node attributes: 0.40517068161
# Coeficiente de agrupamiento de G:0.03636002886
# Centro de G:[0, 12, 14, 22, 25]
# Diametro de G:7
# Periferia de G:
# [37, 42, 56, 76, 77, 93]
# Radio de G:4
# Coeficiente de Small World: 0.8859811434997901
# Omega coeficiente: 0.8712182981958435

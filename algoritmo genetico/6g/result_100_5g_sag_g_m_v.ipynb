# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sag__g_m_v.npy")
p_gen = np.load("solucion_sag__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.3,0.25,0.2,0.15,0.1])
s0=np.random.rand(n)
crimen=5
tipo="sag"
modelo="g_m_v"
lamda={"A":0,"B":0.05,"C":0.1,"D":0.25,"E":0.5}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,save=True,file="graph_100_5g_sag.pdf")

# %%
plt.plot(p_gen)

# %%
plot(modelo=modelo,s=s0,vertices=vecinos,lamda=lamda,save=True,f="simulate_100_5g_sag.pdf")
# Out:
# 0.585364565583189

# %%
homofilia(vecinos)
# Out:
# 0.5766129032258065

# %%
mixing_matrix(G,crimen)
# Out:
# array([[0.27419355, 0.0766129 , 0.03629032, 0.01209677, 0.00604839],
#        [0.0766129 , 0.15725806, 0.03225806, 0.02217742, 0.00806452],
#        [0.03629032, 0.03225806, 0.08467742, 0.01008065, 0.00604839],
#        [0.01209677, 0.02217742, 0.01008065, 0.04435484, 0.00201613],
#        [0.00604839, 0.00806452, 0.00604839, 0.00201613, 0.01612903]])

# %%
grafica_grado_nodos(vecinos)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 248
# Average degree:   4.9600
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.041
# Densidad de G: 0.050101010101
# degree assortativity:-0.0014134147321893443
# assortativity for node attributes: 0.403313397951
# Coeficiente de agrupamiento de G:0.0540151515152
# Centro de G:[45, 50]
# Diametro de G:8
# Periferia de G:
# [92, 99]
# Radio de G:4
# Coeficiente de Small World: 1.102079747404427
# Omega coeficiente: 0.8346555431270857

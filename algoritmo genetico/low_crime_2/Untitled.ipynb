# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
sys.path.append("/home/cpulido/all/PoS/algoritmo genetico/")


from pos import *

# %%
solucion=np.load("solucion_sg__g_m_v.npy")
p_gen = np.load("solucion_sg__g_m_v__p_gen.npy")

# %%
n=100
porcentaje_crimen=np.array([0.34,0.33,0.33])
s0=np.random.rand(n)
crimen=3
tipo="sg"
modelo="g_m_v"
lamda={"A":0,"B":0.05,"C":0.1}

# %%
dist_crimn=dist_crimen(crimen=crimen,n=n,porcentaje=porcentaje_crimen)
vecinos=convert_state_to_vecinos(state=solucion,dist_crimen=dist_crimn,n=n)
G=convert_vertices_to_graph(vecinos)

# %%
draw_graph(G,crime=crimen,fear=s0,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,file="low_crime2_graph.pdf")

# %%
porcentaje(vecinos)
# Out:
# {'A': 0.34000000000000014, 'B': 0.3300000000000001, 'C': 0.3300000000000001}

# %%
plot(modelo=modelo,lamda=lamda,s=s0,vertices=vecinos,legends={"A":"Immune","B":"Susceptible","C":"Highly Susceptible"},save=True,f="low_crime2_simulate.pdf")
# Out:
# 0.48743226003926765

# %%
homofilia(vecinos)
# Out:
# 0.6

# %%
assor(G)
# Out:
# 0.6953337314305909

# %%
mixing_matrix(G)
# Out:
# array([[0.244, 0.106, 0.036],
#        [0.106, 0.088, 0.058],
#        [0.036, 0.058, 0.268]])

# %%
plt.plot(p_gen)

# %%
ver_medidas(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 250
# Average degree:   5.0000
# Numero minimo de nodos que deben ser removidos para desconectar G :1
# average clustering coefficient of G: 0.084
# Densidad de G: 0.050505050505050504
# degree assortativity:-0.09532484110310385
# assortativity for node attributes: 0.39066746286118176
# Coeficiente de agrupamiento de G:0.08382611832611833
# Centro de G:[0, 5, 6, 7, 8, 11, 14, 16, 19, 27, 33, 46, 48, 55, 59, 66, 83, 94, 99]
# Diametro de G:6
# Periferia de G:
# [12, 17, 26, 29, 31, 42, 44, 45, 49, 68, 74, 76, 77, 79, 88, 97]
# Radio de G:4
# Coeficiente de Small World: 1.4513802572817012
# Omega coeficiente: 0.7665369356458132

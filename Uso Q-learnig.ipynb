# %%
import numpy as np
from pos import *
from simulate import g
import matplotlib.pyplot as plt

# %%
Q=np.load("Q_values/Q_9000.npy").item()
len(Q)
# Out:
# 51279

# %%
vertices0=read("6.graph")[0]
vertices=vertices0
soriginal=np.array(Q.keys()[np.random.randint(len(Q.keys()))])#mod.generate("small.graph")
s0=soriginal
vertices
# Out:
# [[0, 0.5, 4],
#  [1, 0.05, 5, 3],
#  [2, 0, 5],
#  [3, 0.05, 1],
#  [4, 0.5, 0, 5],
#  [5, 0.5, 1, 2, 4]]

# %%
p=g(vertices,soriginal)
p,homofilia(vertices)
# Out:
# (0.8225053166284798, 0.6)

# %%
for i in range(15):
    s,r,a,vertices=exec_act(s0,vertices,0.9,0.85,Q,False)
    print(s)
    p=g(vertices,s)
    print("Accion:",a)
    print("PoS",p)
    print("Porcentaje",porcentaje(vertices,True))
    print("Homofilia",homofilia(vertices))
    print("-------------------------------")
    s0=s
    plt.show()
# Out:
# [0.87435    0.69115862 0.77937407 0.64984302 0.87435    0.75922229]
# ('Accion:', '<> des (5, 4)')
# ('PoS', 0.8645738205930164)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.5)
# -------------------------------
# [0.96384333 0.78579199 0.87100189 0.85939968 0.97110209 0.85944528]
# ('Accion:', '>< con (3, 0)')
# ('PoS', 0.8998402374622433)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.4)
# -------------------------------
# [0.96270218 0.72813833 0.66959172 0.84512207 0.81962758 0.68546653]
# ('Accion:', '>< con (5, 4)')
# ('PoS', 0.8610005163287949)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.5)
# -------------------------------
# [0.98281462 0.77578738 0.88358549 0.74191808 0.98236198 0.87934209]
# ('Accion:', '<> des (3, 0)')
# ('PoS', 0.8205654972583118)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.6)
# -------------------------------
# [0.88439305 0.68756566 0.79055257 0.6485274  0.88439305 0.76513337]
# ('Accion:', '<> des (4, 5)')
# ('PoS', 0.8441056906280832)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.5)
# -------------------------------
# [0.9696775  0.72434277 0.76683687 0.66995957 0.9696775  0.83780518]
# ('Accion:', '>< con (2, 1)')
# ('PoS', 0.8084633665647946)
# ('Porcentaje', {0.5: 0.5, 0: 0.16666666666666666, 0.05: 0.3333333333333333})
# ('Homofilia', 0.4)
# -------------------------------
# [0.96939825 0.66887987 0.65623515 0.68213153 0.96939825 0.65640872]
# ('Accion:', 'Cambio de nivel de crimen del sujeto 0 a 0.05')
# ('PoS', 0.7572157068386536)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.3333333333333333, 0.05: 0.5})
# ('Homofilia', 0.2)
# -------------------------------
# [0.51585895 0.75127759 0.82319014 0.59199457 0.52697431 0.95595792]
# ('Accion:', '>< con (3, 4)')
# ('PoS', 0.827280079730049)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.3333333333333333, 0.05: 0.5})
# ('Homofilia', 0.16666666666666666)
# -------------------------------
# [0.95599876 0.69908231 0.76464861 0.57854053 0.95599876 0.93954004]
# ('Accion:', '<> des (4, 3)')
# ('PoS', 0.7424623738989449)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.3333333333333333, 0.05: 0.5})
# ('Homofilia', 0.2)
# -------------------------------
# [0.12914126 0.4922881  0.5224164  0.45473337 0.12914126 0.57064686]
# ('Accion:', 'Cambio de nivel de crimen del sujeto 4 a 0.05')
# ('PoS', 0.6356995900217163)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.4)
# -------------------------------
# [0.26935577 0.70422196 0.70422196 0.59757621 0.26935577 0.94058006]
# ('Accion:', '>< con (2, 3)')
# ('PoS', 0.6134655397203248)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.3333333333333333)
# -------------------------------
# [0.33750481 0.54667235 0.49461268 0.37007644 0.32581773 0.90564736]
# ('Accion:', '>< con (2, 0)')
# ('PoS', 0.5067976938709455)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.2857142857142857)
# -------------------------------
# [0.69710279 0.41089204 0.47529987 0.44683286 0.73385272 0.41089021]
# ('Accion:', '<> des (1, 3)')
# ('PoS', 0.6053405848895197)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.16666666666666666)
# -------------------------------
# [0.68189487 0.77694642 0.68039918 0.57563396 0.5904656  0.94369594]
# ('Accion:', '>< con (0, 5)')
# ('PoS', 0.7410247782415785)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.14285714285714285)
# -------------------------------
# [0.71163979 0.76352813 0.71000252 0.67173167 0.72546272 0.7606138 ]
# ('Accion:', '>< con (1, 4)')
# ('PoS', 0.6474368163613253)
# ('Porcentaje', {0: 0.16666666666666666, 0.5: 0.16666666666666666, 0.05: 0.6666666666666666})
# ('Homofilia', 0.25)
# -------------------------------

# %%
vertices0=read("6.graph")[0]
print(homofilia(vertices0))
print(soriginal)
vertices0
# Out:
# 0.6
# [0.4 0.6 0.9 0.4 0.4 0.8]
# [[0, 0.5, 4],
#  [1, 0.05, 5, 3],
#  [2, 0, 5],
#  [3, 0.05, 1],
#  [4, 0.5, 0, 5],
#  [5, 0.5, 1, 2, 4]]

# %%
print(homofilia(vertices))
print(s)
vertices
# Out:
# 0.25
# [0.71163979 0.76352813 0.71000252 0.67173167 0.72546272 0.7606138 ]
# [[0, 0.05, 4, 2, 5],
#  [1, 0.05, 5, 2, 4],
#  [2, 0, 5, 1, 3, 0],
#  [3, 0.05, 2],
#  [4, 0.05, 0, 1],
#  [5, 0.5, 1, 2, 0]]

# %%
p=g(vertices0,soriginal)
p,homofilia(vertices0)
# Out:
# (0.8162485143130598, 0.6)

# %%
p=g(vertices,soriginal)
p,homofilia(vertices)
# Out:
# (0.6549842300950939, 0.25)

# %%
p=g(vertices,soriginal)
p,homofilia(vertices)
# Out:
# (0.6735487006094569, 0.25)

# %%
p=g(vertices,soriginal)
p,homofilia(vertices)
# Out:
# (0.6407294572700662, 0.25)
